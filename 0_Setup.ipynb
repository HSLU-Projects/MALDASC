# %% [markdown]
# # Setup

# %%
import os

# %%
# !unzip previous_work.zip
# Out:
# Archive:  previous_work.zip
#    creating: previous_work/
#   inflating: previous_work/command_snippets.sh
#    creating: previous_work/configs/
#    creating: previous_work/configs/diffdet/
#   inflating: previous_work/configs/diffdet/Base-DiffusionDet.yaml
#   inflating: previous_work/configs/diffdet/diffdet.dentex.swinbase.disease.yaml
#   inflating: previous_work/configs/diffdet/diffdet.dentex.swinbase.quadrant.yaml
#    creating: previous_work/configs/dino/
#   inflating: previous_work/configs/dino/coco_transformer.py
#   inflating: previous_work/configs/dino/DINO_4scale_cls32.py
#   inflating: previous_work/configs/dino/DINO_4scale_cls4.py
#   inflating: previous_work/configs/dino/DINO_4scale_swin_cls32.py
#   inflating: previous_work/configs/dino/DINO_4scale_swin_cls4.py
#    creating: previous_work/configs/yolo/
#   inflating: previous_work/configs/yolo/dentex_disease_all_dataset.yaml
#   inflating: previous_work/configs/yolo/dentex_disease_dataset.yaml
# ...

# %% [markdown]
# ## Download and extract train data

# %%
# !wget "https://zenodo.org/records/7812323/files/training_data.zip"
# Out:
# --2024-03-22 14:37:12--  https://zenodo.org/records/7812323/files/training_data.zip
# Resolving zenodo.org (zenodo.org)... 188.185.79.172, 188.184.103.159, 188.184.98.238, ...
# Connecting to zenodo.org (zenodo.org)|188.185.79.172|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10927391529 (10G) [application/octet-stream]
# Saving to: ‘training_data.zip’
#
# training_data.zip   100%[===================>]  10.18G  94.7MB/s    in 2m 50s
#
# 2024-03-22 14:40:03 (61.3 MB/s) - ‘training_data.zip’ saved [10927391529/10927391529]

# %%
destination_path = './previous_work/dentex_dataset'

if not os.path.exists(destination_path):
    os.makedirs(destination_path)

# %%
# !unzip "./training_data.zip" -d './previous_work/dentex_dataset'
# Out:
# Archive:  ./training_data.zip
#    creating: destination_path/training_data/
#    creating: destination_path/training_data/quadrant/
#   inflating: destination_path/training_data/quadrant/train_quadrant.json
#    creating: destination_path/training_data/quadrant/xrays/
#   inflating: destination_path/training_data/quadrant/xrays/train_184.png
#   inflating: destination_path/training_data/quadrant/xrays/train_351.png
#   inflating: destination_path/training_data/quadrant/xrays/train_412.png
#   inflating: destination_path/training_data/quadrant/xrays/train_598.png
#   inflating: destination_path/training_data/quadrant/xrays/train_287.png
#   inflating: destination_path/training_data/quadrant/xrays/train_431.png
#   inflating: destination_path/training_data/quadrant/xrays/train_679.png
#   inflating: destination_path/training_data/quadrant/xrays/train_516.png
#   inflating: destination_path/training_data/quadrant/xrays/train_297.png
# ...

# %%
old_dir_path = './previous_work/dentex_dataset/train_dataset'
new_dir_path = './previous_work/dentex_dataset/origin'
os.rename(old_dir_path, new_dir_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 3
#       1 old_dir_path = './previous_work/dentex_dataset/train_dataset'
#       2 new_dir_path = './previous_work/dentex_dataset/origin'
# ----> 3 os.rename(old_dir_path, new_dir_path)
#
# FileNotFoundError: [Errno 2] No such file or directory: './previous_work/dentex_dataset/train_dataset' -> './previous_work/dentex_dataset/origin'

# %% [markdown]
# ## Prepare data
